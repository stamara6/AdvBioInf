# %%
#Question: Where (country, city) is the best place to get a new cheese supplier given the demand for cheese and the ?

# %% [markdown]
# ##### Taken from https://github.com/catherinedevlin/ipython-sql

# %% [markdown]
# # Examples of using SQL from within a python notebook

# %%
# ! runs a command in terminal (BASH)
#!/ext/anaconda3/bin/pip install --user sql
#!/ext/anaconda3/bin/pip install --user ipython-sql
# RUN ONLY ONCE
#!/ext/anaconda3/bin/pip install --user PyVCF
# Out:
# ...
#   Running setup.py bdist_wheel for sql ... -
# \
# done
#   Stored in directory: /home/user/.cache/pip/wheels/af/5b/8c/55ef1a3096a17698b77b3fbe2cb5ea6b3a6143ba81839849fd
# Successfully built sql
# ...
#   Running setup.py bdist_wheel for prettytable ... -
# \
# done
#   Stored in directory: /home/user/.cache/pip/wheels/b6/90/7b/1c22b89217d0eba6d5f406e562365ebee804f0d4595b2bdbcd
# Successfully built prettytable
# ...
#   Running setup.py bdist_wheel for PyVCF ... -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# done
#   Stored in directory: /home/user/.cache/pip/wheels/4c/cb/3a/76a743f5fb96613d53bb60ce20e67546af54610a85e1a0fa17
# Successfully built PyVCF
# ...

# %%
import sql
import vcf
# Out:
# /ext/anaconda3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: During startup -
#   warnings.warn(x, RRuntimeWarning)
# /ext/anaconda3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Warning messages:
#
#   warnings.warn(x, RRuntimeWarning)
# /ext/anaconda3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 1: package ‘methods’ was built under R version 3.4.2
#
#   warnings.warn(x, RRuntimeWarning)
# /ext/anaconda3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 2: package ‘datasets’ was built under R version 3.4.2
#
#   warnings.warn(x, RRuntimeWarning)
# /ext/anaconda3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 3: package ‘utils’ was built under R version 3.4.2
#
#   warnings.warn(x, RRuntimeWarning)
# ...

# %%
#pip install ipython-sql
#pip install sql
#pip install sqlparse

# %%
# %load_ext sql

# %%
# %sql sqlite://
# Out:
# 'Connected: None@None'

# %%
reader = vcf.VCFReader(open('PIK3CA.vcf'))
mutation_list = [];
for idx,record in enumerate(reader):
    mutation_list.append([idx, record.CHROM, record.POS, record.REF, record.ALT, record.ID])
print(mutation_list)
# Out:
# [[0, '3', 178916581, 'T', [C], None], [1, '3', 178916644, 'T', [G], None], [2, '3', 178916645, 'G', [T], 'COSM582519'], [3, '3', 178916651, 'T', [C], 'COSM1420723'], [4, '3', 178916931, 'C', [A], 'COSM166340'], [5, '3', 178917005, 'A', [G], 'rs3729674'], [6, '3', 178917478, 'G', [A], 'COSM751'], [7, '3', 178919190, 'C', [A], None], [8, '3', 178921407, 'C', [T], None], [9, '3', 178921525, 'T', [A], None], [10, '3', 178921553, 'T', [A], 'COSM754'], [11, '3', 178922274, 'C', [A], 'rs2699896'], [12, '3', 178922277, 'C', [T], None], [13, '3', 178922364, 'G', [T], 'COSM4391168'], [14, '3', 178922430, 'A', [G], 'rs3729679'], [15, '3', 178927345, 'T', [C], 'rs3729682'], [16, '3', 178927401, 'T', [A], None], [17, '3', 178927410, 'A', [G], 'COSM328028;rs3729680'], [18, '3', 178927969, 'T', [A], None], [19, '3', 178928098, 'T', [G], None], [20, '3', 178936082, 'G', [A], 'COSM760'], [21, '3', 178936091, 'G', [A], 'COSM763'], [22, '3', 178937726, 'G', [A], None], [23, '3', 178937744, 'A', [T], No
# ...

# %%
# %sql CREATE TABLE sql_mutations ("record_id", "chrom", "pos", "ref", "alt", "id");
for row in mutation_list:
        sql_str = "INSERT INTO sql_mutations VALUES (%s, %s, %s, '%s', '%s', '%s')" %(row[0],row[1],row[2],row[3],row[4],row[5])
        # %sql $sql_str;
# %sql select * from sql_mutations
# Out:
# Done.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# Done.
# <table>
#     <tr>
#         <th>record_id</th>
#         <th>chrom</th>
#         <th>pos</th>
#         <th>ref</th>
#         <th>alt</th>
#         <th>id</th>
#     </tr>
#     <tr>
#         <td>0</td>
#         <td>3</td>
#         <td>178916581</td>
#         <td>T</td>
#         <td>[C]</td>
#         <td>None</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>3</td>
# ...

# %%
reader = vcf.VCFReader(open('PIK3CA.vcf'))
sample_list = [];
for idx, record in enumerate(reader):
    for sample in record.samples:
        sample_list.append([sample.sample, idx, sample["GT"], sample["AD"], sample["DP"], sample["GQ"], sample["PL"]])
print(sample_list)
# Out:
# WARNING: some intermediate output was truncated.
# WARNING: Some output was deleted.

# %%
# %sql CREATE TABLE sql_samples ("sample_id", "record_id", "GT", "AD", "DF", "GQ", "PL");
for row in sample_list:
        sql_str = "INSERT INTO sql_samples VALUES ('%s', %s, '%s', '%s', %s, '%s', '%s')" %(row[0],row[1],row[2],row[3],row[4],row[5],row[6])
        # %sql $sql_str;
# %sql select record_id from sql_samples
# Out:
# Done.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# ...

# %%
# %sql SELECT * FROM sql_mutations LIMIT 3
# Out:
# Done.
# <table>
#     <tr>
#         <th>record_id</th>
#         <th>chrom</th>
#         <th>pos</th>
#         <th>ref</th>
#         <th>alt</th>
#         <th>id</th>
#     </tr>
#     <tr>
#         <td>0</td>
#         <td>3</td>
#         <td>178916581</td>
#         <td>T</td>
#         <td>[C]</td>
#         <td>None</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>3</td>
#         <td>178916644</td>
#         <td>T</td>
#         <td>[G]</td>
#         <td>None</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>3</td>
#         <td>178916645</td>
#         <td>G</td>
#         <td>[T]</td>
#         <td>COSM582519</td>
#     </tr>
# </table>

# %%
# %sql SELECT * FROM sql_samples LIMIT 3
# Out:
# Done.
# <table>
#     <tr>
#         <th>sample_id</th>
#         <th>record_id</th>
#         <th>GT</th>
#         <th>AD</th>
#         <th>DF</th>
#         <th>GQ</th>
#         <th>PL</th>
#     </tr>
#     <tr>
#         <td>009T</td>
#         <td>0</td>
#         <td>0/0</td>
#         <td>[11, 0]</td>
#         <td>11</td>
#         <td>33</td>
#         <td>[0, 33, 495]</td>
#     </tr>
#     <tr>
#         <td>011T</td>
#         <td>0</td>
#         <td>0/0</td>
#         <td>[11, 0]</td>
#         <td>11</td>
#         <td>21</td>
#         <td>[0, 21, 315]</td>
#     </tr>
#     <tr>
#         <td>015R</td>
#         <td>0</td>
#         <td>0/0</td>
#         <td>[21, 0]</td>
#         <td>21</td>
#         <td>18</td>
#         <td>[0, 18, 1090]</td>
#     </tr>
# </table>

# %%
# %sql SELECT sample_id FROM sql_samples INNER JOIN sql_mutations ON sql_samples.record_id = sql_mutations.record_id WHERE GT = '0/1' AND pos = 178936091
# Out:
# Done.
# <table>
#     <tr>
#         <th>sample_id</th>
#     </tr>
#     <tr>
#         <td>032T</td>
#     </tr>
#     <tr>
#         <td>103T</td>
#     </tr>
#     <tr>
#         <td>110T</td>
#     </tr>
#     <tr>
#         <td>MBC037T</td>
#     </tr>
#     <tr>
#         <td>MBC515</td>
#     </tr>
# </table>

# %%
#JdL: Excllent work, no additions, keep it up :)
